# %%
import pandas as pd
import numpy as np

# %%
 data=pd.read_csv("project.csv.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.head(15)
# Out:
#                Name            Team  Number Position  Age  Height  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1       Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2      John Holland  Boston Celtics      30       SG   27  06-May     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# 5      Amir Johnson  Boston Celtics      90       PF   29  06-Sep     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21  06-Aug     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25     7-0     238
# 8      Terry Rozier  Boston Celtics      12       PG   22  06-Feb     190
# 9      Marcus Smart  Boston Celtics      36       PG   22  06-Apr     220
# 10  Jared Sullinger  Boston Celtics       7        C   24  06-Sep     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27  05-Sep     185
# ...

# %%
data.tail(15)
# Out:
#                Name       Team  Number Position  Age  Height  Weight  \
# 443      Trey Burke  Utah Jazz       3       PG   23  06-Jan     191
# 444      Alec Burks  Utah Jazz      10       SG   24  06-Jun     214
# 445      Dante Exum  Utah Jazz      11       PG   20  06-Jun     190
# 446  Derrick Favors  Utah Jazz      15       PF   24  06-Oct     265
# 447     Rudy Gobert  Utah Jazz      27        C   23  07-Jan     245
# 448  Gordon Hayward  Utah Jazz      20       SF   26  06-Aug     226
# 449     Rodney Hood  Utah Jazz       5       SG   23  06-Aug     206
# 450      Joe Ingles  Utah Jazz       2       SF   28  06-Aug     226
# 451   Chris Johnson  Utah Jazz      23       SF   26  06-Jun     206
# 452      Trey Lyles  Utah Jazz      41       PF   20  06-Oct     234
# 453    Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203
# 454       Raul Neto  Utah Jazz      25       PG   24  06-Jan     179
# 455    Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
data["Height"] = np.random.uniform(150,180, size = len(data))
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.903686     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 454      Raul Neto       Utah Jazz      25       PG   24  163.982467     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.263810     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College     Salary
# ...

# %%
x = data["Number"].mean()
data["Number"].fillna(x,inplace = True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.903686     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 454      Raul Neto       Utah Jazz      25       PG   24  163.982467     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.263810     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College     Salary
# ...

# %%
x = data["Age"].mean()
data["Age"].fillna(x,inplace = True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.903686     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 454      Raul Neto       Utah Jazz      25       PG   24  163.982467     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.263810     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College     Salary
# ...

# %%
x = data["Weight"].mean()
data["Weight"].fillna(x, inplace = True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.903686     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 454      Raul Neto       Utah Jazz      25       PG   24  163.982467     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.263810     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College     Salary
# ...

# %%
x = data["Salary"].mean()
data["Salary"].fillna(x, inplace = True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.903686     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 454      Raul Neto       Utah Jazz      25       PG   24  163.982467     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.263810     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College        Salary
# ...

# %%
data.drop_duplicates(inplace = True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.903686     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 454      Raul Neto       Utah Jazz      25       PG   24  163.982467     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  166.263810     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College        Salary
# ...

# %%
data.dropna(subset=["College"], inplace=True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  165.741458     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  172.811430     235
# 2     John Holland  Boston Celtics      30       SG   27  158.098486     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  179.270722     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21  166.805735     235
# ..             ...             ...     ...      ...  ...         ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26  172.945512     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  171.534521     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  159.923919     203
# 456    Jeff Withey       Utah Jazz      24        C   26  157.711361     231
# 457       Priyanka       Utah Jazz      34        C   25  170.751596     231
#
#                College        Salary
# ...

# %%
data.shape
# Out:
# (374, 9)

# %%
unique_team = data["Team"].unique()
print(unique_team)
# Out:
# ['Boston Celtics' 'Brooklyn Nets' 'New York Knicks' 'Philadelphia 76ers'
#  'Toronto Raptors' 'Golden State Warriors' 'Los Angeles Clippers'
#  'Los Angeles Lakers' 'Phoenix Suns' 'Sacramento Kings' 'Chicago Bulls'
#  'Cleveland Cavaliers' 'Detroit Pistons' 'Indiana Pacers'
#  'Milwaukee Bucks' 'Dallas Mavericks' 'Houston Rockets'
#  'Memphis Grizzlies' 'New Orleans Pelicans' 'San Antonio Spurs'
#  'Atlanta Hawks' 'Charlotte Hornets' 'Miami Heat' 'Orlando Magic'
#  'Washington Wizards' 'Denver Nuggets' 'Minnesota Timberwolves'
#  'Oklahoma City Thunder' 'Portland Trail Blazers' 'Utah Jazz']

# %%
team_count = data["Team"].value_counts()
print(team_count)
# Out:
# Memphis Grizzlies         17
# New Orleans Pelicans      16
# Portland Trail Blazers    15
# Philadelphia 76ers        15
# Detroit Pistons           15
# Milwaukee Bucks           14
# Oklahoma City Thunder     14
# Los Angeles Clippers      14
# Boston Celtics            13
# Washington Wizards        13
# Charlotte Hornets         13
# Phoenix Suns              13
# Sacramento Kings          13
# Brooklyn Nets             13
# Dallas Mavericks          12
# Indiana Pacers            12
# Cleveland Cavaliers       12
# Chicago Bulls             12
# Los Angeles Lakers        12
# Golden State Warriors     12
# Houston Rockets           11
# San Antonio Spurs         11
# Atlanta Hawks             11
# Miami Heat                11
# New York Knicks           11
# Utah Jazz                 11
# Orlando Magic             10
# Toronto Raptors           10
# Denver Nuggets             9
# Minnesota Timberwolves     9
# Name: Team, dtype: int64

# %%
tot_emp = len(data)
print(tot_emp)
# Out:
# 374

# %%
percentage = (team_count/tot_emp)*100
print(percentage)
# Out:
# Memphis Grizzlies         4.545455
# New Orleans Pelicans      4.278075
# Portland Trail Blazers    4.010695
# Philadelphia 76ers        4.010695
# Detroit Pistons           4.010695
# Milwaukee Bucks           3.743316
# Oklahoma City Thunder     3.743316
# Los Angeles Clippers      3.743316
# Boston Celtics            3.475936
# Washington Wizards        3.475936
# Charlotte Hornets         3.475936
# Phoenix Suns              3.475936
# Sacramento Kings          3.475936
# Brooklyn Nets             3.475936
# Dallas Mavericks          3.208556
# Indiana Pacers            3.208556
# Cleveland Cavaliers       3.208556
# Chicago Bulls             3.208556
# Los Angeles Lakers        3.208556
# Golden State Warriors     3.208556
# Houston Rockets           2.941176
# San Antonio Spurs         2.941176
# Atlanta Hawks             2.941176
# Miami Heat                2.941176
# New York Knicks           2.941176
# Utah Jazz                 2.941176
# Orlando Magic             2.673797
# ...

# %%
position_group = data.groupby("Position")["Name"].apply((list))
for position,names in position_group.items():
    print(f"Employees in positions{position}:")
    for name in names:
        print(name)
        print
# Out:
# Employees in positionsC:
# Kelly Olynyk
# Jared Sullinger
# Tyler Zeller
# Brook Lopez
# Henry Sims
# Robin Lopez
# Joel Embiid
# Jahlil Okafor
# Andrew Bogut
# Festus Ezeli
# Marreese Speights
# Cole Aldrich
# DeAndre Jordan
# Tarik Black
# Roy Hibbert
# Robert Sacre
# Alex Len
# Alan Williams
# Willie Cauley-Stein
# DeMarcus Cousins
# Kosta Koufos
# Joakim Noah
# Sasha Kaun
# Tristan Thompson
# Joel Anthony
# Aron Baynes
# Andre Drummond
# Jordan Hill
# Greg Monroe
# Miles Plumlee
# JaVale McGee
# Matt Bonner
# Tim Duncan
# Al Horford
# Frank Kaminsky III
# Cody Zeller
# Hassan Whiteside
# Dewayne Dedmon
# Nikola Vucevic
# JJ Hickson
# Gorgui Dieng
# Karl-Anthony Towns
# Steven Adams
# Enes Kanter
# Nazr Mohammed
# Ed Davis
# Chris Kaman
# Mason Plumlee
# Jeff Withey
# Priyanka
# Employees in positionsPF:
# Jordan Mickey
# Chris McCullough
# Willie Reed
# Thomas Robinson
# Thaddeus Young
# Lou Amundson
# Kyle O'Quinn
# Derrick Williams
# Elton Brand
# Richaun Holmes
# Carl Landry
# ...

# %%
age_group=data["Age"].value_counts()
print(age_group)
# Out:
# 25    43
# 24    43
# 27    36
# 23    34
# 26    32
# 28    28
# 22    23
# 30    20
# 29    18
# 31    17
# 20    15
# 21    14
# 36     9
# 32     9
# 35     8
# 33     8
# 34     7
# 38     3
# 19     2
# 37     2
# 40     2
# 39     1
# Name: Age, dtype: int64

# %%
age_grp = age_group.idxmax()
print("age group of most employees worked is",age_grp)
# Out:
# age group of most employees worked is 25

# %%
team_position_salary = data.groupby(["Team","Position"])["Salary"].sum()

max_spend_team_position = team_position_salary.idxmax()
max_spend_salary = team_position_salary.max()

print(f"higest spending team and position")
print(f"highest spending team : {max_spend_team_position[0]}")
print(f"highest spending position : {max_spend_team_position[1]}")
print(f"salary : {max_spend_salary}")
# Out:
# higest spending team and position
# highest spending team : Miami Heat
# highest spending position : PF
# salary : 30591395.0

# %%
import matplotlib.pyplot as plt

# %%
age = data["Age"]
salary = data["Salary"]

correlation = age.corr(salary)
print(f"correlation between age and salary:{correlation}")

plt.figure(figsize=(10,10))
plt.scatter(age,salary)
plt.title("CORRELATION BETWEEN AGE AND SALARY")
plt.xlabel("AGE")
plt.ylabel("SALARY")
plt.show()
# Out:
# correlation between age and salary:0.15775114505522594
